# %%
# !pip install opencv-python

# %%
import cv2

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
image = cv2.imread('google.jpg')

# %%
print('Image type:', type(image))
print('Image dimension:', image.shape)
# Out:
# Image type: <class 'numpy.ndarray'>
# Image dimension: (800, 1200, 3)

# %%
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
rgb_image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb_image)
plt.axis(False)
plt.show()

# %%
cv2.imwrite('image.jpg', image)
# Out:
# True

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image_shape = (600,600,3)
black_image = np.zeros(shape=image_shape, dtype=np.int16)

# %%
plt.imshow(black_image)
plt.axis(False)
plt.show()

# %%
image_shape = (600,600,3)
white_image = np.zeros(shape=image_shape, dtype=np.int16)

# %%
white_image.fill(255)

# %%
plt.imshow(white_image)
plt.show()

# %%
image_shape = (600,600,3)
image = np.zeros(shape=image_shape, dtype=np.int16)

# %%
line = cv2.line(black_image,(599,0),(0,599),(100,0,150),4)

# %%
plt.imshow(line)

# %%
line = cv2.line(white_image,(599,0),(0,599),(255,0,0),4)

# %%
plt.imshow(line)

# %%
img_shape=(600,600,3)

# %%
white_image = np.zeros(shape=img_shape, dtype=np.int16)

# %%
white_image.fill(255)

# %%
circle = cv2.circle(white_image,(300,300), 100, (255,0,0),6)

plt.imshow(circle)

# %%
img_shape=(600,600,3)
black_image = np.zeros(shape=img_shape,dtype=np.int16)

# %%
rectangle = cv2.rectangle(black_image,(200,200),(400,500),(0,255,0),5)
plt.imshow(rectangle)

# %%
img_shape=(600,600,3)
black_image=np.zeros(shape=img_shape,dtype=np.int16)

# %%
rectangle=cv2.rectangle(black_image,(200,200),(400,500),(0,255,0),-1)
plt.imshow(rectangle)

# %%
img_shape=(600,600,3)
black_image=np.zeros(shape=img_shape,dtype=np.int16)

text = cv2.putText(black_image, 'Thanksgiving',(10,500),cv2.FONT_HERSHEY_SIMPLEX, 3, (255,0,0),5,cv2.LINE_AA)

plt.imshow(text)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('tajmahal.jpg')

# %%
rgb_image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb_image)

# %%
image_resized = cv2.resize(rgb_image,(1400,1000), interpolation=cv2.INTER_NEAREST)
plt.imshow(image_resized)

# %%
import cv2

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
image = cv2.imread('messi.png')

# %%
rgb_image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb_image)

# %%
image_flip = cv2.flip(rgb_image,1)
plt.imshow(image_flip)

# %%
image_flip = cv2.flip(rgb_image, 0)
plt.imshow(image_flip)

# %%
image_flip = cv2.flip(rgb_image,-1)
plt.imshow(image_flip)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('nature.jpeg')

# %%
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)

# %%
alpha_=1
beta_=50

# %%
image_change = cv2.addWeighted(rgb_image, alpha_, np.zeros(image.shape,image.dtype),0,beta_)

plt.imshow(image_change)

# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread('tajmahal.jpg')

# %%
rgb_image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb_image)

# %%
plt.imshow(image)

# %%
image_blur = cv2.blur(rgb_image,(15,15))

# %%
plt.imshow(image_blur)

# %%
image_blur2 = cv2.GaussianBlur(rgb_image, (15,15),0)
plt.imshow(image_blur2)

# %%
image_blur3 = cv2.medianBlur(rgb_image,15)
plt.imshow(image_blur3)

# %%
image = cv2.imread('messi.png')

# %%
image_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(image_gray,cmap='gray')

# %%
haar_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
faces_coordinates = haar_cascade.detectMultiScale(image_gray, scaleFactor=1.3, minNeighbors=3)

# %%
for (p,q,r,s) in faces_coordinates:
    cv2.rectangle(image,(p,q),(p+r,q+s),(255,255,0),2)

# %%
image_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)

# %%
image = cv2.imread('barcelona.jpeg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
faces_coordinates = haar_cascade.detectMultiScale(image_gray, scaleFactor=1.3, minNeighbors=3)

# %%
for (x1,y1,x2,y2) in faces_coordinates:
    cv2.rectangle(image,(x1,y1),(x1+x2,y1+y2),(255,255,0),2)

# %%
image_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb)
