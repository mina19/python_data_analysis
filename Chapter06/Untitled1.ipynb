# %%
import pandas as pd

# %%
df = pd.read_json('employee.json')

# %%
df.head()
# Out:
#             name   age   income gender  department grade
# 0    Allen Smith  45.0      NaN   None  Operations    G3
# 1        S Kumar   NaN  16000.0      F     Finance    G0
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2
# 3      Ying Chin  45.0  65000.0      F       Sales    G3
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2

# %%
df2 = pd.read_hdf('employee.h5','table')

# %%
df2
# Out:
#             name   age   income gender  department grade
# 0    Allen Smith  45.0      NaN    NaN  Operations    G3
# 1        S Kumar   NaN  16000.0      F     Finance    G0
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2
# 3      Ying Chin  45.0  65000.0      F       Sales    G3
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2
# 5  Satyam Sharma   NaN  62000.0    NaN       Sales    G3
# 6   James Authur  54.0      NaN      F  Operations    G3
# 7     Josh Wills  54.0  52000.0      F     Finance    G3
# 8       Leo Duck  23.0  98000.0      M       Sales    G4

# %%
df.to_hdf('employee.h5', 'table', append=True, index=True)

# %%
df3 = pd.read_hdf('employee.h5', 'table')

# %%
df3
# Out:
#             name   age   income gender  department grade
# 0    Allen Smith  45.0      NaN    NaN  Operations    G3
# 1        S Kumar   NaN  16000.0      F     Finance    G0
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2
# 3      Ying Chin  45.0  65000.0      F       Sales    G3
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2
# 5  Satyam Sharma   NaN  62000.0    NaN       Sales    G3
# 6   James Authur  54.0      NaN      F  Operations    G3
# 7     Josh Wills  54.0  52000.0      F     Finance    G3
# 8       Leo Duck  23.0  98000.0      M       Sales    G4
# 0    Allen Smith  45.0      NaN    NaN  Operations    G3
# 1        S Kumar   NaN  16000.0      F     Finance    G0
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2
# 3      Ying Chin  45.0  65000.0      F       Sales    G3
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2
# 5  Satyam Sharma   NaN  62000.0    NaN       Sales    G3
# ...

# %%
df
# Out:
#             name   age   income gender  department grade
# 0    Allen Smith  45.0      NaN   None  Operations    G3
# 1        S Kumar   NaN  16000.0      F     Finance    G0
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2
# 3      Ying Chin  45.0  65000.0      F       Sales    G3
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2
# 5  Satyam Sharma   NaN  62000.0   None       Sales    G3
# 6   James Authur  54.0      NaN      F  Operations    G3
# 7     Josh Wills  54.0  52000.0      F     Finance    G3
# 8       Leo Duck  23.0  98000.0      M       Sales    G4

# %%
table_url = 'https://en.wikipedia.org/wiki/List_of_sovereign_states_and_dependent_territories_in_North_America'

# %%
df_list = pd.read_html(table_url)

# %%
df_list
# Out:
# [    Flag                     English short name  \
#  0    NaN               Antigua and Barbuda[n 1]
#  1    NaN                      Bahamas, The[n 1]
#  2    NaN                          Barbados[n 1]
#  3    NaN                       Belize[n 1][n 2]
#  4    NaN                            Canada[n 3]
#  5    NaN                        Costa Rica[n 2]
#  6    NaN                                   Cuba
#  7    NaN                          Dominica[n 1]
#  8    NaN                Dominican Republic[n 2]
#  9    NaN                       El Salvador[n 2]
#  10   NaN                           Grenada[n 1]
#  11   NaN                         Guatemala[n 2]
#  12   NaN                             Haiti[n 1]
#  13   NaN                          Honduras[n 2]
#  14   NaN                           Jamaica[n 1]
#  15   NaN                            Mexico[n 3]
#  16   NaN                         Nicaragua[n 2]
#  17   NaN                            Panama[n 2]
# ...

# %%
print('Number of DataFrames:', len(df_list))
# Out:
# Number of DataFrames: 8

# %%
df_list[0].head()
# Out:
#    Flag        English short name            English long name  \
# 0   NaN  Antigua and Barbuda[n 1]          Antigua and Barbuda
# 1   NaN         Bahamas, The[n 1]  Commonwealth of The Bahamas
# 2   NaN             Barbados[n 1]                     Barbados
# 3   NaN          Belize[n 1][n 2]                       Belize
# 4   NaN               Canada[n 3]                       Canada
#
#           Domestic short name(s)     Capital               Currency  \
# 0   English: Antigua and Barbuda  St. John's  East Caribbean dollar
# 1               English: Bahamas      Nassau        Bahamian dollar
# 2              English: Barbados  Bridgetown       Barbadian dollar
# 3                English: Belize    Belmopan          Belize dollar
# 4  English: CanadaFrench: Canada      Ottawa        Canadian dollar
#
#    Population
# 0       97118
# 1      389482
# 2      287025
# 3      390353
# 4    35151728

# %%
df_list[1].to_html('country.html')

# %%
# !pip install pyarrow

# %%
df
# Out:
#             name   age   income gender  department grade
# 0    Allen Smith  45.0      NaN   None  Operations    G3
# 1        S Kumar   NaN  16000.0      F     Finance    G0
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2
# 3      Ying Chin  45.0  65000.0      F       Sales    G3
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2
# 5  Satyam Sharma   NaN  62000.0   None       Sales    G3
# 6   James Authur  54.0      NaN      F  Operations    G3
# 7     Josh Wills  54.0  52000.0      F     Finance    G3
# 8       Leo Duck  23.0  98000.0      M       Sales    G4

# %%
df.to_parquet('employee.parquet',engine='pyarrow')

# %%
employee_df = pd.read_parquet('employee.parquet', engine='pyarrow')

# %%
employee_df
# Out:
#             name   age   income gender  department grade
# 0    Allen Smith  45.0      NaN   None  Operations    G3
# 1        S Kumar   NaN  16000.0      F     Finance    G0
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2
# 3      Ying Chin  45.0  65000.0      F       Sales    G3
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2
# 5  Satyam Sharma   NaN  62000.0   None       Sales    G3
# 6   James Authur  54.0      NaN      F  Operations    G3
# 7     Josh Wills  54.0  52000.0      F     Finance    G3
# 8       Leo Duck  23.0  98000.0      M       Sales    G4

# %%
df = pd.read_csv('demo.csv', header=None)

# %%
df
# Out:
#     0   1   2
# 0  14  32  33
# 1  24  45  26
# 2  27  38  39

# %%
df.to_pickle('demo_obj.pkl')

# %%
df
# Out:
#     0   1   2
# 0  14  32  33
# 1  24  45  26
# 2  27  38  39

# %%
pickle_obj = pd.read_pickle('demo_obj.pkl')

# %%
pickle_obj
# Out:
#     0   1   2
# 0  14  32  33
# 1  24  45  26
# 2  27  38  39

# %%
import sqlite3

# %%
conn = sqlite3.connect('employee.db')

# %%
cur = conn.cursor()

# %%
cur.execute('select name from sqlite_master where type="table";')

# %%
print(cur.fetchall())
# Out:
# [('emp',)]

# %%
cur.execute("create table emp (eid int, salary int)")

# %%
cur.execute("insert into emp values (105, 57000)")

# %%
conn.commit()

# %%
cur.execute('select * from emp')

# %%
print(cur.fetchall())
# Out:
# [(105, 57000)]

# %%
conn.close()

# %%
# !pip install pymysql

# %%
import pymysql

# %%
connection = pymysql.connect(host='localhost', user='root', password='Thorne_40', db='sakila', charset='utf8mb4', cursorclass=pymysql.cursors.DictCursor)

# %%
cur = connection.cursor()

# %%
sql_qery = 'select a.last_name, f.title from film_actor fa inner join actor a on fa.actor_id = a.actor_id inner join film f on fa.film_id = f.film_id where fa.actor_id = 100'

# %%
cur.execute(sql_qery)
# Out:
# 24

# %%
cur.fetchall()
# Out:
# [{'last_name': 'DEPP', 'title': 'ALONE TRIP'},
#  {'last_name': 'DEPP', 'title': 'CANYON STOCK'},
#  {'last_name': 'DEPP', 'title': 'DRAGON SQUAD'},
#  {'last_name': 'DEPP', 'title': 'HEAVENLY GUN'},
#  {'last_name': 'DEPP', 'title': 'HELLFIGHTERS SIERRA'},
#  {'last_name': 'DEPP', 'title': 'LEATHERNECKS DWARFS'},
#  {'last_name': 'DEPP', 'title': 'MASSACRE USUAL'},
#  {'last_name': 'DEPP', 'title': 'ORDER BETRAYED'},
#  {'last_name': 'DEPP', 'title': 'RANDOM GO'},
#  {'last_name': 'DEPP', 'title': 'REBEL AIRPORT'},
#  {'last_name': 'DEPP', 'title': 'SALUTE APOLLO'},
#  {'last_name': 'DEPP', 'title': 'SENSE GREEK'},
#  {'last_name': 'DEPP', 'title': 'SNATCHERS MONTEZUMA'},
#  {'last_name': 'DEPP', 'title': 'STING PERSONAL'},
#  {'last_name': 'DEPP', 'title': 'STORY SIDE'},
#  {'last_name': 'DEPP', 'title': 'SWEET BROTHERHOOD'},
#  {'last_name': 'DEPP', 'title': 'TAXI KICK'},
#  {'last_name': 'DEPP', 'title': 'TREASURE COMMAND'},
#  {'last_name': 'DEPP', 'title': 'TYCOON GATHERING'},
# ...

# %%
connection.close()

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector
import pandas as pd

# %%
connection = mysql.connector.connect(user='root', password='Thorne_40', host='localhost',database='sakila')

# %%
cur = connection.cursor()

# %%
cur.execute("select * from actor")

# %%
records = cur.fetchall()

# %%
for i in records:
    print(i)
# Out:
# (1, 'PENELOPE', 'GUINESS', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (2, 'NICK', 'WAHLBERG', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (3, 'ED', 'CHASE', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (4, 'JENNIFER', 'DAVIS', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (5, 'JOHNNY', 'LOLLOBRIGIDA', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (6, 'BETTE', 'NICHOLSON', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (7, 'GRACE', 'MOSTEL', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (8, 'MATTHEW', 'JOHANSSON', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (9, 'JOE', 'SWANK', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (10, 'CHRISTIAN', 'GABLE', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (11, 'ZERO', 'CAGE', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (12, 'KARL', 'BERRY', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (13, 'UMA', 'WOOD', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (14, 'VIVIEN', 'BERGEN', datetime.datetime(2006, 2, 15, 4, 34, 33))
# ...

# %%
df = pd.DataFrame(records)

# %%
df.head()
# Out:
#    0         1             2                   3
# 0  1  PENELOPE       GUINESS 2006-02-15 04:34:33
# 1  2      NICK      WAHLBERG 2006-02-15 04:34:33
# 2  3        ED         CHASE 2006-02-15 04:34:33
# 3  4  JENNIFER         DAVIS 2006-02-15 04:34:33
# 4  5    JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33

# %%
df
# Out:
#        0         1             2                   3
# 0      1  PENELOPE       GUINESS 2006-02-15 04:34:33
# 1      2      NICK      WAHLBERG 2006-02-15 04:34:33
# 2      3        ED         CHASE 2006-02-15 04:34:33
# 3      4  JENNIFER         DAVIS 2006-02-15 04:34:33
# 4      5    JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..   ...       ...           ...                 ...
# 195  196      BELA        WALKEN 2006-02-15 04:34:33
# 196  197     REESE          WEST 2006-02-15 04:34:33
# 197  198      MARY        KEITEL 2006-02-15 04:34:33
# 198  199     JULIA       FAWCETT 2006-02-15 04:34:33
# 199  200     THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
df.columns = [i[0] for i in cur.description]

# %%
df.columns
# Out:
# Index(['actor_id', 'first_name', 'last_name', 'last_update'], dtype='object')

# %%
df
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
cur.execute("select * from customer")

# %%
records = cur.fetchall()

# %%
for i in records:
    print(i)
# Out:
# (1, 1, 'MARY', 'SMITH', 'MARY.SMITH@sakilacustomer.org', 5, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20))
# (2, 1, 'PATRICIA', 'JOHNSON', 'PATRICIA.JOHNSON@sakilacustomer.org', 6, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20))
# (3, 1, 'LINDA', 'WILLIAMS', 'LINDA.WILLIAMS@sakilacustomer.org', 7, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20))
# (4, 2, 'BARBARA', 'JONES', 'BARBARA.JONES@sakilacustomer.org', 8, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20))
# (5, 1, 'ELIZABETH', 'BROWN', 'ELIZABETH.BROWN@sakilacustomer.org', 9, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20))
# (6, 2, 'JENNIFER', 'DAVIS', 'JENNIFER.DAVIS@sakilacustomer.org', 10, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20))
# ...

# %%
df = pd.DataFrame(records)

# %%
df.head()
# Out:
#    0  1          2         3                                    4  5  6  \
# 0  1  1       MARY     SMITH        MARY.SMITH@sakilacustomer.org  5  1
# 1  2  1   PATRICIA   JOHNSON  PATRICIA.JOHNSON@sakilacustomer.org  6  1
# 2  3  1      LINDA  WILLIAMS    LINDA.WILLIAMS@sakilacustomer.org  7  1
# 3  4  2    BARBARA     JONES     BARBARA.JONES@sakilacustomer.org  8  1
# 4  5  1  ELIZABETH     BROWN   ELIZABETH.BROWN@sakilacustomer.org  9  1
#
#                     7                   8
# 0 2006-02-14 22:04:36 2006-02-15 04:57:20
# 1 2006-02-14 22:04:36 2006-02-15 04:57:20
# 2 2006-02-14 22:04:36 2006-02-15 04:57:20
# 3 2006-02-14 22:04:36 2006-02-15 04:57:20
# 4 2006-02-14 22:04:36 2006-02-15 04:57:20

# %%
cur.description
# Out:
# [('customer_id', 2, None, None, None, None, 0, 16931, 63),
#  ('store_id', 1, None, None, None, None, 0, 20521, 63),
#  ('first_name', 253, None, None, None, None, 0, 4097, 45),
#  ('last_name', 253, None, None, None, None, 0, 20489, 45),
#  ('email', 253, None, None, None, None, 1, 0, 45),
#  ('address_id', 2, None, None, None, None, 0, 20521, 63),
#  ('active', 1, None, None, None, None, 0, 1, 63),
#  ('create_date', 12, None, None, None, None, 0, 4225, 63),
#  ('last_update', 7, None, None, None, None, 1, 9344, 63)]

# %%
df.columns = [i[0] for i in cur.description]

# %%
df.head()
# Out:
#    customer_id  store_id first_name last_name  \
# 0            1         1       MARY     SMITH
# 1            2         1   PATRICIA   JOHNSON
# 2            3         1      LINDA  WILLIAMS
# 3            4         2    BARBARA     JONES
# 4            5         1  ELIZABETH     BROWN
#
#                                  email  address_id  active  \
# 0        MARY.SMITH@sakilacustomer.org           5       1
# 1  PATRICIA.JOHNSON@sakilacustomer.org           6       1
# 2    LINDA.WILLIAMS@sakilacustomer.org           7       1
# 3     BARBARA.JONES@sakilacustomer.org           8       1
# 4   ELIZABETH.BROWN@sakilacustomer.org           9       1
#
#           create_date         last_update
# 0 2006-02-14 22:04:36 2006-02-15 04:57:20
# 1 2006-02-14 22:04:36 2006-02-15 04:57:20
# 2 2006-02-14 22:04:36 2006-02-15 04:57:20
# 3 2006-02-14 22:04:36 2006-02-15 04:57:20
# 4 2006-02-14 22:04:36 2006-02-15 04:57:20

# %%
connection.close()

# %%
from sqlalchemy import create_engine

# %%
# !pip install pymongo

# %%
import pymongo

# %%
client = pymongo.MongoClient()

# %%
db = client.employee

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'employee')

# %%
collection = db.emp

# %%
employee_salary = {'eid':114, 'salary':25000}

# %%
collection.insert_one(employee_salary)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-132-fb5939d7d44b> in <module>
# ----> 1 collection.insert_one(employee_salary)
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     703         write_concern = self._write_concern_for(session)
#     704         return InsertOneResult(
# --> 705             self._insert(document,
#     706                          write_concern=write_concern,
#     707                          bypass_doc_val=bypass_document_validation,
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     618         """Internal insert helper."""
#     619         if isinstance(docs, abc.Mapping):
# --> 620             return self._insert_one(
# ...

# %%
collection

# %%
pip install cassandra-driver
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pony
# Out:
# ...
#   Created wheel for pony: filename=pony-0.7.14-py3-none-any.whl size=351283 sha256=ebe57a7f13c66d1500cdf0fe10c012562d0821a86753dcc8801e38d93d3576e1
#   Stored in directory: c:\users\min-a\appdata\local\pip\cache\wheels\2d\b3\a9\81748d9c5bc350f169663cae2b7a2b7549c020ea694c7e839e
# Successfully built pony
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pony.orm import *

# %%
db = Database()

# %%
class Actor(db.Entity):
    actor_id = PrimaryKey(int,auto=True)
    first_name = Required(str)
    last_name = Required(str)

# %%
show(Actor)
# Out:
# class Actor(Entity):
#     actor_id = PrimaryKey(int, auto=True)
#     first_name = Required(str)
#     last_name = Required(str)

# %%
db.bind('mysql', host='localhost', user='root', passwd='Thorne_40', db='sakila')

# %%
db.generate_mapping(create_tables=True)

# %%
sql_debug(True)

# %%
select(a for a in Actor)[:].show()
# Out:
# SELECT `a`.`actor_id`, `a`.`first_name`, `a`.`last_name`
# FROM `actor` `a`
#
# actor_id|first_name |last_name
# --------+-----------+------------
# 1       |PENELOPE   |GUINESS
# 2       |NICK       |WAHLBERG
# 3       |ED         |CHASE
# 4       |JENNIFER   |DAVIS
# 5       |JOHNNY     |LOLLOBRIGIDA
# 6       |BETTE      |NICHOLSON
# 7       |GRACE      |MOSTEL
# 8       |MATTHEW    |JOHANSSON
# 9       |JOE        |SWANK
# 10      |CHRISTIAN  |GABLE
# 11      |ZERO       |CAGE
# 12      |KARL       |BERRY
# 13      |UMA        |WOOD
# 14      |VIVIEN     |BERGEN
# 15      |CUBA       |OLIVIER
# 16      |FRED       |COSTNER
# 17      |HELEN      |VOIGHT
# 18      |DAN        |TORN
# 19      |BOB        |FAWCETT
# 20      |LUCILLE    |TRACY
# 21      |KIRSTEN    |PALTROW
# 22      |ELVIS      |MARX
# 23      |SANDRA     |KILMER
# 24      |CAMERON    |STREEP
# 25      |KEVIN      |BLOOM
# 26      |RIP        |CRAWFORD
# 27      |JULIA      |MCQUEEN
# 28      |WOODY      |HOFFMAN
# ...

# %%
db
